# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation

# %%
# config_file = '../config.json'
algorithm = 'proposed'
time_step_length = 1 # in milliseconds
max_iterations = 1000000
mobility_file_path = '../src/sumo/csv/train.csv'
edge_file_path = '../src/inputs/train/edge_servers.json'
vehicle_file_path = '../src/inputs/train/vehicles.json'
mode = 'train'
simulation = Simulation(algorithm, time_step_length, max_iterations, mobility_file_path, mode, edge_file_path, vehicle_file_path);
# Out:
# Edge Server id: 1, x: 166 y: 166
# Edge Server id: 2, x: 500 y: 166
# Edge Server id: 3, x: 833 y: 166
# Edge Server id: 4, x: 166 y: 500
# Edge Server id: 5, x: 500 y: 500
# Edge Server id: 6, x: 833 y: 500
# Edge Server id: 7, x: 166 y: 833
# Edge Server id: 8, x: 500 y: 833
# Edge Server id: 9, x: 833 y: 833
# Initialized 9 edge servers.
# vehicle id: 1 x: 100 y: 200 speed: 4000, direction: 1000
# Initialized 1 vehicles.

# %%
simulation.run()
# Out:
# Running simulation stated!
# Iteration: 1 started  ----------------------------------------------------------------
# task: 1 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 1 ended ----------------------------------------------------------------
# Iteration: 2 started  ----------------------------------------------------------------
# Iteration: 2 ended ----------------------------------------------------------------
# Iteration: 3 started  ----------------------------------------------------------------
# Iteration: 3 ended ----------------------------------------------------------------
# Iteration: 4 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 2 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 4 ended ----------------------------------------------------------------
# Iteration: 5 started  ----------------------------------------------------------------
# Iteration: 5 ended ----------------------------------------------------------------
# Iteration: 6 started  ----------------------------------------------------------------
# Iteration: 6 ended ----------------------------------------------------------------
# Iteration: 7 started  ----------------------------------------------------------------
# task: 3 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 7 ended ----------------------------------------------------------------
# Iteration: 8 started  ----------------------------------------------------------------
# Iteration: 8 ended ----------------------------------------------------------------
# Iteration: 9 started  ----------------------------------------------------------------
# Iteration: 9 ended ----------------------------------------------------------------
# Iteration: 10 started  ----------------------------------------------------------------
# task: 4 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 10 ended ----------------------------------------------------------------
# Iteration: 11 started  ----------------------------------------------------------------
# Iteration: 11 ended ----------------------------------------------------------------
# Iteration: 12 started  ----------------------------------------------------------------
# Iteration: 12 ended ----------------------------------------------------------------
# Iteration: 13 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 5 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 13 ended ----------------------------------------------------------------
# Iteration: 14 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 14 ended ----------------------------------------------------------------
# Iteration: 15 started  ----------------------------------------------------------------
# Iteration: 15 ended ----------------------------------------------------------------
# Iteration: 16 started  ----------------------------------------------------------------
# task: 6 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 16 ended ----------------------------------------------------------------
# Iteration: 17 started  ----------------------------------------------------------------
# Iteration: 17 ended ----------------------------------------------------------------
# Iteration: 18 started  ----------------------------------------------------------------
# Iteration: 18 ended ----------------------------------------------------------------
# Iteration: 19 started  ----------------------------------------------------------------
# task: 7 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 19 ended ----------------------------------------------------------------
# Iteration: 20 started  ----------------------------------------------------------------
# Iteration: 20 ended ----------------------------------------------------------------
# Iteration: 21 started  ----------------------------------------------------------------
# Iteration: 21 ended ----------------------------------------------------------------
# Iteration: 22 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 8 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 22 ended ----------------------------------------------------------------
# Iteration: 23 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 23 ended ----------------------------------------------------------------
# Iteration: 24 started  ----------------------------------------------------------------
# Iteration: 24 ended ----------------------------------------------------------------
# Iteration: 25 started  ----------------------------------------------------------------
# task: 9 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 25 ended ----------------------------------------------------------------
# Iteration: 26 started  ----------------------------------------------------------------
# Iteration: 26 ended ----------------------------------------------------------------
# Iteration: 27 started  ----------------------------------------------------------------
# Iteration: 27 ended ----------------------------------------------------------------
# Iteration: 28 started  ----------------------------------------------------------------
# task: 10 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 28 ended ----------------------------------------------------------------
# Iteration: 29 started  ----------------------------------------------------------------
# Iteration: 29 ended ----------------------------------------------------------------
# Iteration: 30 started  ----------------------------------------------------------------
# Iteration: 30 ended ----------------------------------------------------------------
# Iteration: 31 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 11 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 31 ended ----------------------------------------------------------------
# Iteration: 32 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 32 ended ----------------------------------------------------------------
# Iteration: 33 started  ----------------------------------------------------------------
# Iteration: 33 ended ----------------------------------------------------------------
# Iteration: 34 started  ----------------------------------------------------------------
# task: 12 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 34 ended ----------------------------------------------------------------
# Iteration: 35 started  ----------------------------------------------------------------
# Iteration: 35 ended ----------------------------------------------------------------
# Iteration: 36 started  ----------------------------------------------------------------
# Iteration: 36 ended ----------------------------------------------------------------
# Iteration: 37 started  ----------------------------------------------------------------
# task: 13 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 37 ended ----------------------------------------------------------------
# Iteration: 38 started  ----------------------------------------------------------------
# Iteration: 38 ended ----------------------------------------------------------------
# Iteration: 39 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 39 ended ----------------------------------------------------------------
# Iteration: 40 started  ----------------------------------------------------------------
# task: 14 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 40 ended ----------------------------------------------------------------
# Iteration: 41 started  ----------------------------------------------------------------
# Iteration: 41 ended ----------------------------------------------------------------
# Iteration: 42 started  ----------------------------------------------------------------
# Iteration: 42 ended ----------------------------------------------------------------
# Iteration: 43 started  ----------------------------------------------------------------
# task: 15 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 43 ended ----------------------------------------------------------------
# Iteration: 44 started  ----------------------------------------------------------------
# Iteration: 44 ended ----------------------------------------------------------------
# Iteration: 45 started  ----------------------------------------------------------------
# Iteration: 45 ended ----------------------------------------------------------------
# Iteration: 46 started  ----------------------------------------------------------------
# task: 16 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 46 ended ----------------------------------------------------------------
# Iteration: 47 started  ----------------------------------------------------------------
# Iteration: 47 ended ----------------------------------------------------------------
# Iteration: 48 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 48 ended ----------------------------------------------------------------
# Iteration: 49 started  ----------------------------------------------------------------
# task: 17 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 49 ended ----------------------------------------------------------------
# Iteration: 50 started  ----------------------------------------------------------------
# Iteration: 50 ended ----------------------------------------------------------------
# Iteration: 51 started  ----------------------------------------------------------------
# Iteration: 51 ended ----------------------------------------------------------------
# Iteration: 52 started  ----------------------------------------------------------------
# task: 18 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 52 ended ----------------------------------------------------------------
# Iteration: 53 started  ----------------------------------------------------------------
# Iteration: 53 ended ----------------------------------------------------------------
# Iteration: 54 started  ----------------------------------------------------------------
# Iteration: 54 ended ----------------------------------------------------------------
# Iteration: 55 started  ----------------------------------------------------------------
# task: 19 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 55 ended ----------------------------------------------------------------
# Iteration: 56 started  ----------------------------------------------------------------
# Iteration: 56 ended ----------------------------------------------------------------
# Iteration: 57 started  ----------------------------------------------------------------
# Iteration: 57 ended ----------------------------------------------------------------
# Iteration: 58 started  ----------------------------------------------------------------
# task: 20 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 58 ended ----------------------------------------------------------------
# Iteration: 59 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 59 ended ----------------------------------------------------------------
# Iteration: 60 started  ----------------------------------------------------------------
# Iteration: 60 ended ----------------------------------------------------------------
# Iteration: 61 started  ----------------------------------------------------------------
# task: 21 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 61 ended ----------------------------------------------------------------
# Iteration: 62 started  ----------------------------------------------------------------
# Iteration: 62 ended ----------------------------------------------------------------
# Iteration: 63 started  ----------------------------------------------------------------
# Iteration: 63 ended ----------------------------------------------------------------
# Iteration: 64 started  ----------------------------------------------------------------
# task: 22 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 64 ended ----------------------------------------------------------------
# Iteration: 65 started  ----------------------------------------------------------------
# Iteration: 65 ended ----------------------------------------------------------------
# Iteration: 66 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 66 ended ----------------------------------------------------------------
# Iteration: 67 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 23 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 67 ended ----------------------------------------------------------------
# Iteration: 68 started  ----------------------------------------------------------------
# Iteration: 68 ended ----------------------------------------------------------------
# Iteration: 69 started  ----------------------------------------------------------------
# Iteration: 69 ended ----------------------------------------------------------------
# Iteration: 70 started  ----------------------------------------------------------------
# task: 24 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 70 ended ----------------------------------------------------------------
# Iteration: 71 started  ----------------------------------------------------------------
# Iteration: 71 ended ----------------------------------------------------------------
# Iteration: 72 started  ----------------------------------------------------------------
# Iteration: 72 ended ----------------------------------------------------------------
# Iteration: 73 started  ----------------------------------------------------------------
# task: 25 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 73 ended ----------------------------------------------------------------
# Iteration: 74 started  ----------------------------------------------------------------
# Iteration: 74 ended ----------------------------------------------------------------
# Iteration: 75 started  ----------------------------------------------------------------
# Iteration: 75 ended ----------------------------------------------------------------
# Iteration: 76 started  ----------------------------------------------------------------
# task: 26 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 76 ended ----------------------------------------------------------------
# Iteration: 77 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 77 ended ----------------------------------------------------------------
# Iteration: 78 started  ----------------------------------------------------------------
# Iteration: 78 ended ----------------------------------------------------------------
# Iteration: 79 started  ----------------------------------------------------------------
# task: 27 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 79 ended ----------------------------------------------------------------
# Iteration: 80 started  ----------------------------------------------------------------
# Iteration: 80 ended ----------------------------------------------------------------
# Iteration: 81 started  ----------------------------------------------------------------
# Iteration: 81 ended ----------------------------------------------------------------
# Iteration: 82 started  ----------------------------------------------------------------
# task: 28 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 82 ended ----------------------------------------------------------------
# Iteration: 83 started  ----------------------------------------------------------------
# Iteration: 83 ended ----------------------------------------------------------------
# Iteration: 84 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 84 ended ----------------------------------------------------------------
# Iteration: 85 started  ----------------------------------------------------------------
# task: 29 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 85 ended ----------------------------------------------------------------
# Iteration: 86 started  ----------------------------------------------------------------
# Iteration: 86 ended ----------------------------------------------------------------
# Iteration: 87 started  ----------------------------------------------------------------
# Iteration: 87 ended ----------------------------------------------------------------
# Iteration: 88 started  ----------------------------------------------------------------
# task: 30 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 88 ended ----------------------------------------------------------------
# Iteration: 89 started  ----------------------------------------------------------------
# Iteration: 89 ended ----------------------------------------------------------------
# Iteration: 90 started  ----------------------------------------------------------------
# Iteration: 90 ended ----------------------------------------------------------------
# Iteration: 91 started  ----------------------------------------------------------------
# task: 31 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 91 ended ----------------------------------------------------------------
# Iteration: 92 started  ----------------------------------------------------------------
# Iteration: 92 ended ----------------------------------------------------------------
# Iteration: 93 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 93 ended ----------------------------------------------------------------
# Iteration: 94 started  ----------------------------------------------------------------
# task: 32 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 94 ended ----------------------------------------------------------------
# Iteration: 95 started  ----------------------------------------------------------------
# Iteration: 95 ended ----------------------------------------------------------------
# Iteration: 96 started  ----------------------------------------------------------------
# Iteration: 96 ended ----------------------------------------------------------------
# Iteration: 97 started  ----------------------------------------------------------------
# task: 33 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 97 ended ----------------------------------------------------------------
# Iteration: 98 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 98 ended ----------------------------------------------------------------
# Iteration: 99 started  ----------------------------------------------------------------
# Iteration: 99 ended ----------------------------------------------------------------
# Iteration: 100 started  ----------------------------------------------------------------
# task: 34 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 100 ended ----------------------------------------------------------------
# Iteration: 101 started  ----------------------------------------------------------------
# Iteration: 101 ended ----------------------------------------------------------------
# Iteration: 102 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 102 ended ----------------------------------------------------------------
# Iteration: 103 started  ----------------------------------------------------------------
# task: 35 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 103 ended ----------------------------------------------------------------
# Iteration: 104 started  ----------------------------------------------------------------
# Iteration: 104 ended ----------------------------------------------------------------
# Iteration: 105 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 105 ended ----------------------------------------------------------------
# Iteration: 106 started  ----------------------------------------------------------------
# task: 36 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 106 ended ----------------------------------------------------------------
# Iteration: 107 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 107 ended ----------------------------------------------------------------
# Iteration: 108 started  ----------------------------------------------------------------
# Iteration: 108 ended ----------------------------------------------------------------
# Iteration: 109 started  ----------------------------------------------------------------
# task: 37 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 109 ended ----------------------------------------------------------------
# Iteration: 110 started  ----------------------------------------------------------------
# Iteration: 110 ended ----------------------------------------------------------------
# Iteration: 111 started  ----------------------------------------------------------------
# Iteration: 111 ended ----------------------------------------------------------------
# Iteration: 112 started  ----------------------------------------------------------------
# task: 38 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 112 ended ----------------------------------------------------------------
# Iteration: 113 started  ----------------------------------------------------------------
# Iteration: 113 ended ----------------------------------------------------------------
# Iteration: 114 started  ----------------------------------------------------------------
# Iteration: 114 ended ----------------------------------------------------------------
# Iteration: 115 started  ----------------------------------------------------------------
# task: 39 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 115 ended ----------------------------------------------------------------
# Iteration: 116 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 116 ended ----------------------------------------------------------------
# Iteration: 117 started  ----------------------------------------------------------------
# Iteration: 117 ended ----------------------------------------------------------------
# Iteration: 118 started  ----------------------------------------------------------------
# task: 40 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 118 ended ----------------------------------------------------------------
# Iteration: 119 started  ----------------------------------------------------------------
# Iteration: 119 ended ----------------------------------------------------------------
# Iteration: 120 started  ----------------------------------------------------------------
# Iteration: 120 ended ----------------------------------------------------------------
# Iteration: 121 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 41 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 121 ended ----------------------------------------------------------------
# Iteration: 122 started  ----------------------------------------------------------------
# Iteration: 122 ended ----------------------------------------------------------------
# Iteration: 123 started  ----------------------------------------------------------------
# Iteration: 123 ended ----------------------------------------------------------------
# Iteration: 124 started  ----------------------------------------------------------------
# task: 42 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 124 ended ----------------------------------------------------------------
# Iteration: 125 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 125 ended ----------------------------------------------------------------
# Iteration: 126 started  ----------------------------------------------------------------
# Iteration: 126 ended ----------------------------------------------------------------
# Iteration: 127 started  ----------------------------------------------------------------
# task: 43 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 127 ended ----------------------------------------------------------------
# Iteration: 128 started  ----------------------------------------------------------------
# Iteration: 128 ended ----------------------------------------------------------------
# Iteration: 129 started  ----------------------------------------------------------------
# Iteration: 129 ended ----------------------------------------------------------------
# Iteration: 130 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 44 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 130 ended ----------------------------------------------------------------
# Iteration: 131 started  ----------------------------------------------------------------
# Iteration: 131 ended ----------------------------------------------------------------
# Iteration: 132 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 132 ended ----------------------------------------------------------------
# Iteration: 133 started  ----------------------------------------------------------------
# task: 45 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 133 ended ----------------------------------------------------------------
# Iteration: 134 started  ----------------------------------------------------------------
# Iteration: 134 ended ----------------------------------------------------------------
# Iteration: 135 started  ----------------------------------------------------------------
# Iteration: 135 ended ----------------------------------------------------------------
# Iteration: 136 started  ----------------------------------------------------------------
# task: 46 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 136 ended ----------------------------------------------------------------
# Iteration: 137 started  ----------------------------------------------------------------
# Iteration: 137 ended ----------------------------------------------------------------
# Iteration: 138 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 138 ended ----------------------------------------------------------------
# Iteration: 139 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 47 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 139 ended ----------------------------------------------------------------
# Iteration: 140 started  ----------------------------------------------------------------
# Iteration: 140 ended ----------------------------------------------------------------
# Iteration: 141 started  ----------------------------------------------------------------
# Iteration: 141 ended ----------------------------------------------------------------
# Iteration: 142 started  ----------------------------------------------------------------
# task: 48 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 142 ended ----------------------------------------------------------------
# Iteration: 143 started  ----------------------------------------------------------------
# Iteration: 143 ended ----------------------------------------------------------------
# Iteration: 144 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 144 ended ----------------------------------------------------------------
# Iteration: 145 started  ----------------------------------------------------------------
# task: 49 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 145 ended ----------------------------------------------------------------
# Iteration: 146 started  ----------------------------------------------------------------
# Iteration: 146 ended ----------------------------------------------------------------
# Iteration: 147 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 147 ended ----------------------------------------------------------------
# Iteration: 148 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 50 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 148 ended ----------------------------------------------------------------
# Iteration: 149 started  ----------------------------------------------------------------
# Iteration: 149 ended ----------------------------------------------------------------
# Iteration: 150 started  ----------------------------------------------------------------
# Iteration: 150 ended ----------------------------------------------------------------
# Iteration: 151 started  ----------------------------------------------------------------
# task: 51 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 151 ended ----------------------------------------------------------------
# Iteration: 152 started  ----------------------------------------------------------------
# Iteration: 152 ended ----------------------------------------------------------------
# Iteration: 153 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 153 ended ----------------------------------------------------------------
# Iteration: 154 started  ----------------------------------------------------------------
# task: 52 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 154 ended ----------------------------------------------------------------
# Iteration: 155 started  ----------------------------------------------------------------
# Iteration: 155 ended ----------------------------------------------------------------
# Iteration: 156 started  ----------------------------------------------------------------
# Iteration: 156 ended ----------------------------------------------------------------
# Iteration: 157 started  ----------------------------------------------------------------
# task: 53 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 157 ended ----------------------------------------------------------------
# Iteration: 158 started  ----------------------------------------------------------------
# Iteration: 158 ended ----------------------------------------------------------------
# Iteration: 159 started  ----------------------------------------------------------------
# Iteration: 159 ended ----------------------------------------------------------------
# Iteration: 160 started  ----------------------------------------------------------------
# task: 54 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 160 ended ----------------------------------------------------------------
# Iteration: 161 started  ----------------------------------------------------------------
# Iteration: 161 ended ----------------------------------------------------------------
# Iteration: 162 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 162 ended ----------------------------------------------------------------
# Iteration: 163 started  ----------------------------------------------------------------
# task: 55 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 163 ended ----------------------------------------------------------------
# Iteration: 164 started  ----------------------------------------------------------------
# Iteration: 164 ended ----------------------------------------------------------------
# Iteration: 165 started  ----------------------------------------------------------------
# Iteration: 165 ended ----------------------------------------------------------------
# Iteration: 166 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 56 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 166 ended ----------------------------------------------------------------
# Iteration: 167 started  ----------------------------------------------------------------
# Iteration: 167 ended ----------------------------------------------------------------
# Iteration: 168 started  ----------------------------------------------------------------
# Iteration: 168 ended ----------------------------------------------------------------
# Iteration: 169 started  ----------------------------------------------------------------
# task: 57 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 169 ended ----------------------------------------------------------------
# Iteration: 170 started  ----------------------------------------------------------------
# Iteration: 170 ended ----------------------------------------------------------------
# Iteration: 171 started  ----------------------------------------------------------------
# Iteration: 171 ended ----------------------------------------------------------------
# Iteration: 172 started  ----------------------------------------------------------------
# task: 58 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 172 ended ----------------------------------------------------------------
# Iteration: 173 started  ----------------------------------------------------------------
# Iteration: 173 ended ----------------------------------------------------------------
# Iteration: 174 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 174 ended ----------------------------------------------------------------
# Iteration: 175 started  ----------------------------------------------------------------
# task: 59 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 175 ended ----------------------------------------------------------------
# Iteration: 176 started  ----------------------------------------------------------------
# Iteration: 176 ended ----------------------------------------------------------------
# Iteration: 177 started  ----------------------------------------------------------------
# Iteration: 177 ended ----------------------------------------------------------------
# Iteration: 178 started  ----------------------------------------------------------------
# task: 60 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 178 ended ----------------------------------------------------------------
# Iteration: 179 started  ----------------------------------------------------------------
# Iteration: 179 ended ----------------------------------------------------------------
# Iteration: 180 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 180 ended ----------------------------------------------------------------
# Iteration: 181 started  ----------------------------------------------------------------
# task: 61 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 181 ended ----------------------------------------------------------------
# Iteration: 182 started  ----------------------------------------------------------------
# Iteration: 182 ended ----------------------------------------------------------------
# Iteration: 183 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 183 ended ----------------------------------------------------------------
# Iteration: 184 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 62 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 184 ended ----------------------------------------------------------------
# Iteration: 185 started  ----------------------------------------------------------------
# Iteration: 185 ended ----------------------------------------------------------------
# Iteration: 186 started  ----------------------------------------------------------------
# Iteration: 186 ended ----------------------------------------------------------------
# Iteration: 187 started  ----------------------------------------------------------------
# task: 63 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 187 ended ----------------------------------------------------------------
# Iteration: 188 started  ----------------------------------------------------------------
# Iteration: 188 ended ----------------------------------------------------------------
# Iteration: 189 started  ----------------------------------------------------------------
# Iteration: 189 ended ----------------------------------------------------------------
# Iteration: 190 started  ----------------------------------------------------------------
# task: 64 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 190 ended ----------------------------------------------------------------
# Iteration: 191 started  ----------------------------------------------------------------
# Iteration: 191 ended ----------------------------------------------------------------
# Iteration: 192 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 192 ended ----------------------------------------------------------------
# Iteration: 193 started  ----------------------------------------------------------------
# task: 65 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 193 ended ----------------------------------------------------------------
# Iteration: 194 started  ----------------------------------------------------------------
# Iteration: 194 ended ----------------------------------------------------------------
# Iteration: 195 started  ----------------------------------------------------------------
# Iteration: 195 ended ----------------------------------------------------------------
# Iteration: 196 started  ----------------------------------------------------------------
# task: 66 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 196 ended ----------------------------------------------------------------
# Iteration: 197 started  ----------------------------------------------------------------
# Iteration: 197 ended ----------------------------------------------------------------
# Iteration: 198 started  ----------------------------------------------------------------
# Iteration: 198 ended ----------------------------------------------------------------
# Iteration: 199 started  ----------------------------------------------------------------
# task: 67 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 199 ended ----------------------------------------------------------------
# Iteration: 200 started  ----------------------------------------------------------------
# Iteration: 200 ended ----------------------------------------------------------------
# Iteration: 201 started  ----------------------------------------------------------------
# Iteration: 201 ended ----------------------------------------------------------------
# Iteration: 202 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 68 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 202 ended ----------------------------------------------------------------
# Iteration: 203 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 203 ended ----------------------------------------------------------------
# Iteration: 204 started  ----------------------------------------------------------------
# Iteration: 204 ended ----------------------------------------------------------------
# Iteration: 205 started  ----------------------------------------------------------------
# task: 69 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 205 ended ----------------------------------------------------------------
# Iteration: 206 started  ----------------------------------------------------------------
# Iteration: 206 ended ----------------------------------------------------------------
# Iteration: 207 started  ----------------------------------------------------------------
# Iteration: 207 ended ----------------------------------------------------------------
# Iteration: 208 started  ----------------------------------------------------------------
# task: 70 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 208 ended ----------------------------------------------------------------
# Iteration: 209 started  ----------------------------------------------------------------
# Iteration: 209 ended ----------------------------------------------------------------
# Iteration: 210 started  ----------------------------------------------------------------
# Iteration: 210 ended ----------------------------------------------------------------
# Iteration: 211 started  ----------------------------------------------------------------
# task: 71 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 211 ended ----------------------------------------------------------------
# Iteration: 212 started  ----------------------------------------------------------------
# Iteration: 212 ended ----------------------------------------------------------------
# Iteration: 213 started  ----------------------------------------------------------------
# Iteration: 213 ended ----------------------------------------------------------------
# Iteration: 214 started  ----------------------------------------------------------------
# task: 72 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 214 ended ----------------------------------------------------------------
# Iteration: 215 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 215 ended ----------------------------------------------------------------
# Iteration: 216 started  ----------------------------------------------------------------
# Iteration: 216 ended ----------------------------------------------------------------
# Iteration: 217 started  ----------------------------------------------------------------
# task: 73 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 217 ended ----------------------------------------------------------------
# Iteration: 218 started  ----------------------------------------------------------------
# Iteration: 218 ended ----------------------------------------------------------------
# Iteration: 219 started  ----------------------------------------------------------------
# Iteration: 219 ended ----------------------------------------------------------------
# Iteration: 220 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 74 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 220 ended ----------------------------------------------------------------
# Iteration: 221 started  ----------------------------------------------------------------
# Iteration: 221 ended ----------------------------------------------------------------
# Iteration: 222 started  ----------------------------------------------------------------
# Iteration: 222 ended ----------------------------------------------------------------
# Iteration: 223 started  ----------------------------------------------------------------
# task: 75 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 223 ended ----------------------------------------------------------------
# Iteration: 224 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 224 ended ----------------------------------------------------------------
# Iteration: 225 started  ----------------------------------------------------------------
# Iteration: 225 ended ----------------------------------------------------------------
# Iteration: 226 started  ----------------------------------------------------------------
# task: 76 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 226 ended ----------------------------------------------------------------
# Iteration: 227 started  ----------------------------------------------------------------
# Iteration: 227 ended ----------------------------------------------------------------
# Iteration: 228 started  ----------------------------------------------------------------
# Iteration: 228 ended ----------------------------------------------------------------
# Iteration: 229 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 77 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 229 ended ----------------------------------------------------------------
# Iteration: 230 started  ----------------------------------------------------------------
# Iteration: 230 ended ----------------------------------------------------------------
# Iteration: 231 started  ----------------------------------------------------------------
# Iteration: 231 ended ----------------------------------------------------------------
# Iteration: 232 started  ----------------------------------------------------------------
# task: 78 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 232 ended ----------------------------------------------------------------
# Iteration: 233 started  ----------------------------------------------------------------
# ...
# Q-table updated!!!!!!!!
# task: 320 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 958 ended ----------------------------------------------------------------
# Iteration: 959 started  ----------------------------------------------------------------
# Iteration: 959 ended ----------------------------------------------------------------
# Iteration: 960 started  ----------------------------------------------------------------
# Iteration: 960 ended ----------------------------------------------------------------
# Iteration: 961 started  ----------------------------------------------------------------
# task: 321 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 961 ended ----------------------------------------------------------------
# Iteration: 962 started  ----------------------------------------------------------------
# Iteration: 962 ended ----------------------------------------------------------------
# Iteration: 963 started  ----------------------------------------------------------------
# Iteration: 963 ended ----------------------------------------------------------------
# Iteration: 964 started  ----------------------------------------------------------------
# task: 322 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 964 ended ----------------------------------------------------------------
# Iteration: 965 started  ----------------------------------------------------------------
# Iteration: 965 ended ----------------------------------------------------------------
# Iteration: 966 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 966 ended ----------------------------------------------------------------
# Iteration: 967 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 323 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 967 ended ----------------------------------------------------------------
# Iteration: 968 started  ----------------------------------------------------------------
# Iteration: 968 ended ----------------------------------------------------------------
# Iteration: 969 started  ----------------------------------------------------------------
# Iteration: 969 ended ----------------------------------------------------------------
# Iteration: 970 started  ----------------------------------------------------------------
# task: 324 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 970 ended ----------------------------------------------------------------
# Iteration: 971 started  ----------------------------------------------------------------
# Iteration: 971 ended ----------------------------------------------------------------
# Iteration: 972 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 972 ended ----------------------------------------------------------------
# Iteration: 973 started  ----------------------------------------------------------------
# task: 325 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 973 ended ----------------------------------------------------------------
# Iteration: 974 started  ----------------------------------------------------------------
# Iteration: 974 ended ----------------------------------------------------------------
# Iteration: 975 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 975 ended ----------------------------------------------------------------
# Iteration: 976 started  ----------------------------------------------------------------
# task: 326 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 976 ended ----------------------------------------------------------------
# Iteration: 977 started  ----------------------------------------------------------------
# Iteration: 977 ended ----------------------------------------------------------------
# Iteration: 978 started  ----------------------------------------------------------------
# Iteration: 978 ended ----------------------------------------------------------------
# Iteration: 979 started  ----------------------------------------------------------------
# task: 327 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 979 ended ----------------------------------------------------------------
# Iteration: 980 started  ----------------------------------------------------------------
# Iteration: 980 ended ----------------------------------------------------------------
# Iteration: 981 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 981 ended ----------------------------------------------------------------
# Iteration: 982 started  ----------------------------------------------------------------
# task: 328 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 982 ended ----------------------------------------------------------------
# Iteration: 983 started  ----------------------------------------------------------------
# Iteration: 983 ended ----------------------------------------------------------------
# Iteration: 984 started  ----------------------------------------------------------------
# Iteration: 984 ended ----------------------------------------------------------------
# Iteration: 985 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 329 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 985 ended ----------------------------------------------------------------
# Iteration: 986 started  ----------------------------------------------------------------
# Iteration: 986 ended ----------------------------------------------------------------
# Iteration: 987 started  ----------------------------------------------------------------
# Iteration: 987 ended ----------------------------------------------------------------
# Iteration: 988 started  ----------------------------------------------------------------
# task: 330 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 988 ended ----------------------------------------------------------------
# Iteration: 989 started  ----------------------------------------------------------------
# Iteration: 989 ended ----------------------------------------------------------------
# Iteration: 990 started  ----------------------------------------------------------------
# Iteration: 990 ended ----------------------------------------------------------------
# Iteration: 991 started  ----------------------------------------------------------------
# task: 331 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 991 ended ----------------------------------------------------------------
# Iteration: 992 started  ----------------------------------------------------------------
# Iteration: 992 ended ----------------------------------------------------------------
# Iteration: 993 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 993 ended ----------------------------------------------------------------
# Iteration: 994 started  ----------------------------------------------------------------
# task: 332 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 994 ended ----------------------------------------------------------------
# Iteration: 995 started  ----------------------------------------------------------------
# Iteration: 995 ended ----------------------------------------------------------------
# Iteration: 996 started  ----------------------------------------------------------------
# Iteration: 996 ended ----------------------------------------------------------------
# Iteration: 997 started  ----------------------------------------------------------------
# task: 333 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 997 ended ----------------------------------------------------------------
# Iteration: 998 started  ----------------------------------------------------------------
# Iteration: 998 ended ----------------------------------------------------------------
# Iteration: 999 started  ----------------------------------------------------------------
# Iteration: 999 ended ----------------------------------------------------------------
# Iteration: 1000 started  ----------------------------------------------------------------
# task: 334 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 1000 ended ----------------------------------------------------------------
# Iteration: 1001 started  ----------------------------------------------------------------
# Iteration: 1001 ended ----------------------------------------------------------------
# Iteration: 1002 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 1002 ended ----------------------------------------------------------------
# Iteration: 1003 started  ----------------------------------------------------------------
# task: 335 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 1003 ended ----------------------------------------------------------------
# Iteration: 1004 started  ----------------------------------------------------------------
# Iteration: 1004 ended ----------------------------------------------------------------
# Iteration: 1005 started  ----------------------------------------------------------------
# Iteration: 1005 ended ----------------------------------------------------------------
# Iteration: 1006 started  ----------------------------------------------------------------
# task: 336 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 1006 ended ----------------------------------------------------------------
# Iteration: 1007 started  ----------------------------------------------------------------
# Iteration: 1007 ended ----------------------------------------------------------------
# Iteration: 1008 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 1008 ended ----------------------------------------------------------------
# Iteration: 1009 started  ----------------------------------------------------------------
# task: 337 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 1009 ended ----------------------------------------------------------------
# Iteration: 1010 started  ----------------------------------------------------------------
# Iteration: 1010 ended ----------------------------------------------------------------
# Iteration: 1011 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 1011 ended ----------------------------------------------------------------
# Iteration: 1012 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 338 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 1012 ended ----------------------------------------------------------------
# Iteration: 1013 started  ----------------------------------------------------------------
# Iteration: 1013 ended ----------------------------------------------------------------
# Iteration: 1014 started  ----------------------------------------------------------------
# Iteration: 1014 ended ----------------------------------------------------------------
# Iteration: 1015 started  ----------------------------------------------------------------
# task: 339 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 1015 ended ----------------------------------------------------------------
# Iteration: 1016 started  ----------------------------------------------------------------
# Iteration: 1016 ended ----------------------------------------------------------------
# Iteration: 1017 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 1017 ended ----------------------------------------------------------------
# Iteration: 1018 started  ----------------------------------------------------------------
# task: 340 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 1018 ended ----------------------------------------------------------------
# Iteration: 1019 started  ----------------------------------------------------------------
# Iteration: 1019 ended ----------------------------------------------------------------
# Iteration: 1020 started  ----------------------------------------------------------------
# Iteration: 1020 ended ----------------------------------------------------------------
# Iteration: 1021 started  ----------------------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3007/3467389145.py in ?()
# ----> 1 simulation.run()
#
# /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/simulation.py in ?(self)
#      43
#      44             if(self.iteration_count % 3 == 1):
#      45                 generate_tasks(self.vehicles, self.iteration_count)
#      46             vehicle_movement_funciton(self.vehicles, self.iteration_count, self.mobilty_file)
# ---> 47             manage_tasks(self.vehicles, self.edge_servers, self.iteration_count)
#      48
#      49
#      50             time.sleep(self.time_step_length)
#
# /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/task_management.py in ?(vehicles, edge_servers, time)
#      37 def manage_tasks(vehicles, edge_servers, time):
#      38
#      39     for vehicle in vehicles:
# ---> 40         handle_undecided_tasks(vehicle, edge_servers)
#      41         is_busy = vehicle.is_busy(time)
#      42         if is_busy == False:
#      43             vehicle.run_new_task(time)
#
# /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/task_management.py in ?(vehicle, edge_servers)
#      22             print(f"task: {task.id} locaction: local at {vehicle.id}, energy:{task.energy}, execution_time:{task.execution_time}")
#      23         elif(action == 1):
#      24             # print(f"task energy {task.energy} ")
#      25             vehicle.unfinished_offload_tasks.append(task)
# ---> 26             closest_edge_server = vehicle.find_closest_edge_server(edge_servers)
#      27             task.execution_location = 1
#      28             task.set_execution_time(closest_edge_server.frequency)
#      29             task.add_transmission_energy(vehicle.transmission_power, closest_edge_server.bandwidth)
#
# /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/classes/vehicle.py in ?(self, edge_servers)
#      99         min_distance = float('inf')
#     100         closest_server = None
#     101         for server in edge_servers:
#     102             distance = ((server.x - self.x)**2 + (server.y - self.y)**2)**0.5
# --> 103             if distance < min_distance:
#     104                 min_distance = distance
#     105                 closest_server = server
#     106         return closest_server
#
# ~/miniconda3/envs/farsi/lib/python3.9/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
