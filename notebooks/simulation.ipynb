# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation

# %%
# config_file = '../config.json'
algorithm = 'proposed'
time_step_length = 1 # in milliseconds
max_iterations = 1000000
mobility_file_path = '../src/sumo/csv/train.csv'
edge_file_path = '../src/inputs/train/edge_servers.json'
vehicle_file_path = '../src/inputs/train/vehicles.json'
mode = 'train'
simulation = Simulation(algorithm, time_step_length, max_iterations, mobility_file_path, mode, edge_file_path, vehicle_file_path);
# Out:
# Edge Server id: 1, x: 166 y: 166
# Edge Server id: 2, x: 500 y: 166
# Edge Server id: 3, x: 833 y: 166
# Edge Server id: 4, x: 166 y: 500
# Edge Server id: 5, x: 500 y: 500
# Edge Server id: 6, x: 833 y: 500
# Edge Server id: 7, x: 166 y: 833
# Edge Server id: 8, x: 500 y: 833
# Edge Server id: 9, x: 833 y: 833
# Initialized 9 edge servers.
# vehicle id: 1 x: 100 y: 200 speed: 4000, direction: 1000
# Initialized 1 vehicles.

# %%
simulation.run()
# Out:
# Running simulation stated!
# Iteration: 1 started  ----------------------------------------------------------------
# task: 1 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 1 ended ----------------------------------------------------------------
# Iteration: 2 started  ----------------------------------------------------------------
# Iteration: 2 ended ----------------------------------------------------------------
# Iteration: 3 started  ----------------------------------------------------------------
# Iteration: 3 ended ----------------------------------------------------------------
# Iteration: 4 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 2 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 4 ended ----------------------------------------------------------------
# Iteration: 5 started  ----------------------------------------------------------------
# Iteration: 5 ended ----------------------------------------------------------------
# Iteration: 6 started  ----------------------------------------------------------------
# Iteration: 6 ended ----------------------------------------------------------------
# Iteration: 7 started  ----------------------------------------------------------------
# task: 3 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 7 ended ----------------------------------------------------------------
# Iteration: 8 started  ----------------------------------------------------------------
# Iteration: 8 ended ----------------------------------------------------------------
# Iteration: 9 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 9 ended ----------------------------------------------------------------
# Iteration: 10 started  ----------------------------------------------------------------
# task: 4 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 10 ended ----------------------------------------------------------------
# Iteration: 11 started  ----------------------------------------------------------------
# Iteration: 11 ended ----------------------------------------------------------------
# Iteration: 12 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 12 ended ----------------------------------------------------------------
# Iteration: 13 started  ----------------------------------------------------------------
# task: 5 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 13 ended ----------------------------------------------------------------
# Iteration: 14 started  ----------------------------------------------------------------
# Iteration: 14 ended ----------------------------------------------------------------
# Iteration: 15 started  ----------------------------------------------------------------
# Iteration: 15 ended ----------------------------------------------------------------
# Iteration: 16 started  ----------------------------------------------------------------
# task: 6 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 16 ended ----------------------------------------------------------------
# Iteration: 17 started  ----------------------------------------------------------------
# Iteration: 17 ended ----------------------------------------------------------------
# Iteration: 18 started  ----------------------------------------------------------------
# Iteration: 18 ended ----------------------------------------------------------------
# Iteration: 19 started  ----------------------------------------------------------------
# task: 7 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 19 ended ----------------------------------------------------------------
# Iteration: 20 started  ----------------------------------------------------------------
# Iteration: 20 ended ----------------------------------------------------------------
# Iteration: 21 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 21 ended ----------------------------------------------------------------
# Iteration: 22 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 8 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 22 ended ----------------------------------------------------------------
# Iteration: 23 started  ----------------------------------------------------------------
# Iteration: 23 ended ----------------------------------------------------------------
# Iteration: 24 started  ----------------------------------------------------------------
# Iteration: 24 ended ----------------------------------------------------------------
# Iteration: 25 started  ----------------------------------------------------------------
# task: 9 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 25 ended ----------------------------------------------------------------
# Iteration: 26 started  ----------------------------------------------------------------
# Iteration: 26 ended ----------------------------------------------------------------
# Iteration: 27 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 27 ended ----------------------------------------------------------------
# Iteration: 28 started  ----------------------------------------------------------------
# task: 10 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 28 ended ----------------------------------------------------------------
# Iteration: 29 started  ----------------------------------------------------------------
# Iteration: 29 ended ----------------------------------------------------------------
# Iteration: 30 started  ----------------------------------------------------------------
# Iteration: 30 ended ----------------------------------------------------------------
# Iteration: 31 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 11 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 31 ended ----------------------------------------------------------------
# Iteration: 32 started  ----------------------------------------------------------------
# Iteration: 32 ended ----------------------------------------------------------------
# Iteration: 33 started  ----------------------------------------------------------------
# Iteration: 33 ended ----------------------------------------------------------------
# Iteration: 34 started  ----------------------------------------------------------------
# task: 12 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 34 ended ----------------------------------------------------------------
# Iteration: 35 started  ----------------------------------------------------------------
# Iteration: 35 ended ----------------------------------------------------------------
# Iteration: 36 started  ----------------------------------------------------------------
# Iteration: 36 ended ----------------------------------------------------------------
# Iteration: 37 started  ----------------------------------------------------------------
# task: 13 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 37 ended ----------------------------------------------------------------
# Iteration: 38 started  ----------------------------------------------------------------
# Iteration: 38 ended ----------------------------------------------------------------
# Iteration: 39 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 39 ended ----------------------------------------------------------------
# Iteration: 40 started  ----------------------------------------------------------------
# task: 14 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 40 ended ----------------------------------------------------------------
# Iteration: 41 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 41 ended ----------------------------------------------------------------
# Iteration: 42 started  ----------------------------------------------------------------
# Iteration: 42 ended ----------------------------------------------------------------
# Iteration: 43 started  ----------------------------------------------------------------
# task: 15 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 43 ended ----------------------------------------------------------------
# Iteration: 44 started  ----------------------------------------------------------------
# Iteration: 44 ended ----------------------------------------------------------------
# Iteration: 45 started  ----------------------------------------------------------------
# Iteration: 45 ended ----------------------------------------------------------------
# Iteration: 46 started  ----------------------------------------------------------------
# task: 16 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 46 ended ----------------------------------------------------------------
# Iteration: 47 started  ----------------------------------------------------------------
# Iteration: 47 ended ----------------------------------------------------------------
# Iteration: 48 started  ----------------------------------------------------------------
# Iteration: 48 ended ----------------------------------------------------------------
# Iteration: 49 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 17 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 49 ended ----------------------------------------------------------------
# Iteration: 50 started  ----------------------------------------------------------------
# Iteration: 50 ended ----------------------------------------------------------------
# Iteration: 51 started  ----------------------------------------------------------------
# Iteration: 51 ended ----------------------------------------------------------------
# Iteration: 52 started  ----------------------------------------------------------------
# task: 18 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 52 ended ----------------------------------------------------------------
# Iteration: 53 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 53 ended ----------------------------------------------------------------
# Iteration: 54 started  ----------------------------------------------------------------
# Iteration: 54 ended ----------------------------------------------------------------
# Iteration: 55 started  ----------------------------------------------------------------
# task: 19 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 55 ended ----------------------------------------------------------------
# Iteration: 56 started  ----------------------------------------------------------------
# Iteration: 56 ended ----------------------------------------------------------------
# Iteration: 57 started  ----------------------------------------------------------------
# Iteration: 57 ended ----------------------------------------------------------------
# Iteration: 58 started  ----------------------------------------------------------------
# task: 20 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 58 ended ----------------------------------------------------------------
# Iteration: 59 started  ----------------------------------------------------------------
# Iteration: 59 ended ----------------------------------------------------------------
# Iteration: 60 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 60 ended ----------------------------------------------------------------
# Iteration: 61 started  ----------------------------------------------------------------
# task: 21 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 61 ended ----------------------------------------------------------------
# Iteration: 62 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 62 ended ----------------------------------------------------------------
# Iteration: 63 started  ----------------------------------------------------------------
# Iteration: 63 ended ----------------------------------------------------------------
# Iteration: 64 started  ----------------------------------------------------------------
# task: 22 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 64 ended ----------------------------------------------------------------
# Iteration: 65 started  ----------------------------------------------------------------
# Iteration: 65 ended ----------------------------------------------------------------
# Iteration: 66 started  ----------------------------------------------------------------
# Iteration: 66 ended ----------------------------------------------------------------
# Iteration: 67 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 23 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 67 ended ----------------------------------------------------------------
# Iteration: 68 started  ----------------------------------------------------------------
# Iteration: 68 ended ----------------------------------------------------------------
# Iteration: 69 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 69 ended ----------------------------------------------------------------
# Iteration: 70 started  ----------------------------------------------------------------
# task: 24 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 70 ended ----------------------------------------------------------------
# Iteration: 71 started  ----------------------------------------------------------------
# Iteration: 71 ended ----------------------------------------------------------------
# Iteration: 72 started  ----------------------------------------------------------------
# Iteration: 72 ended ----------------------------------------------------------------
# Iteration: 73 started  ----------------------------------------------------------------
# task: 25 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 73 ended ----------------------------------------------------------------
# Iteration: 74 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 74 ended ----------------------------------------------------------------
# Iteration: 75 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 75 ended ----------------------------------------------------------------
# Iteration: 76 started  ----------------------------------------------------------------
# task: 26 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 76 ended ----------------------------------------------------------------
# Iteration: 77 started  ----------------------------------------------------------------
# Iteration: 77 ended ----------------------------------------------------------------
# Iteration: 78 started  ----------------------------------------------------------------
# Iteration: 78 ended ----------------------------------------------------------------
# Iteration: 79 started  ----------------------------------------------------------------
# task: 27 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 79 ended ----------------------------------------------------------------
# Iteration: 80 started  ----------------------------------------------------------------
# Iteration: 80 ended ----------------------------------------------------------------
# Iteration: 81 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 81 ended ----------------------------------------------------------------
# Iteration: 82 started  ----------------------------------------------------------------
# task: 28 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 82 ended ----------------------------------------------------------------
# Iteration: 83 started  ----------------------------------------------------------------
# Iteration: 83 ended ----------------------------------------------------------------
# Iteration: 84 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 84 ended ----------------------------------------------------------------
# Iteration: 85 started  ----------------------------------------------------------------
# task: 29 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 85 ended ----------------------------------------------------------------
# Iteration: 86 started  ----------------------------------------------------------------
# Iteration: 86 ended ----------------------------------------------------------------
# Iteration: 87 started  ----------------------------------------------------------------
# Iteration: 87 ended ----------------------------------------------------------------
# Iteration: 88 started  ----------------------------------------------------------------
# task: 30 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 88 ended ----------------------------------------------------------------
# Iteration: 89 started  ----------------------------------------------------------------
# Iteration: 89 ended ----------------------------------------------------------------
# Iteration: 90 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 90 ended ----------------------------------------------------------------
# Iteration: 91 started  ----------------------------------------------------------------
# task: 31 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 91 ended ----------------------------------------------------------------
# Iteration: 92 started  ----------------------------------------------------------------
# Iteration: 92 ended ----------------------------------------------------------------
# Iteration: 93 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 93 ended ----------------------------------------------------------------
# Iteration: 94 started  ----------------------------------------------------------------
# task: 32 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 94 ended ----------------------------------------------------------------
# Iteration: 95 started  ----------------------------------------------------------------
# Iteration: 95 ended ----------------------------------------------------------------
# Iteration: 96 started  ----------------------------------------------------------------
# Iteration: 96 ended ----------------------------------------------------------------
# Iteration: 97 started  ----------------------------------------------------------------
# task: 33 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 97 ended ----------------------------------------------------------------
# Iteration: 98 started  ----------------------------------------------------------------
# Iteration: 98 ended ----------------------------------------------------------------
# Iteration: 99 started  ----------------------------------------------------------------
# Iteration: 99 ended ----------------------------------------------------------------
# Iteration: 100 started  ----------------------------------------------------------------
# task: 34 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 100 ended ----------------------------------------------------------------
# Iteration: 101 started  ----------------------------------------------------------------
# Iteration: 101 ended ----------------------------------------------------------------
# Iteration: 102 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 102 ended ----------------------------------------------------------------
# Iteration: 103 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 35 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 103 ended ----------------------------------------------------------------
# Iteration: 104 started  ----------------------------------------------------------------
# Iteration: 104 ended ----------------------------------------------------------------
# Iteration: 105 started  ----------------------------------------------------------------
# Iteration: 105 ended ----------------------------------------------------------------
# Iteration: 106 started  ----------------------------------------------------------------
# task: 36 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 106 ended ----------------------------------------------------------------
# Iteration: 107 started  ----------------------------------------------------------------
# Iteration: 107 ended ----------------------------------------------------------------
# Iteration: 108 started  ----------------------------------------------------------------
# Iteration: 108 ended ----------------------------------------------------------------
# Iteration: 109 started  ----------------------------------------------------------------
# task: 37 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 109 ended ----------------------------------------------------------------
# Iteration: 110 started  ----------------------------------------------------------------
# Iteration: 110 ended ----------------------------------------------------------------
# Iteration: 111 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 111 ended ----------------------------------------------------------------
# Iteration: 112 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 38 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 112 ended ----------------------------------------------------------------
# Iteration: 113 started  ----------------------------------------------------------------
# Iteration: 113 ended ----------------------------------------------------------------
# Iteration: 114 started  ----------------------------------------------------------------
# Iteration: 114 ended ----------------------------------------------------------------
# Iteration: 115 started  ----------------------------------------------------------------
# task: 39 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 115 ended ----------------------------------------------------------------
# Iteration: 116 started  ----------------------------------------------------------------
# Iteration: 116 ended ----------------------------------------------------------------
# Iteration: 117 started  ----------------------------------------------------------------
# Iteration: 117 ended ----------------------------------------------------------------
# Iteration: 118 started  ----------------------------------------------------------------
# task: 40 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 118 ended ----------------------------------------------------------------
# Iteration: 119 started  ----------------------------------------------------------------
# Iteration: 119 ended ----------------------------------------------------------------
# Iteration: 120 started  ----------------------------------------------------------------
# Iteration: 120 ended ----------------------------------------------------------------
# Iteration: 121 started  ----------------------------------------------------------------
# task: 41 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 121 ended ----------------------------------------------------------------
# Iteration: 122 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 122 ended ----------------------------------------------------------------
# Iteration: 123 started  ----------------------------------------------------------------
# Iteration: 123 ended ----------------------------------------------------------------
# Iteration: 124 started  ----------------------------------------------------------------
# task: 42 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 124 ended ----------------------------------------------------------------
# Iteration: 125 started  ----------------------------------------------------------------
# Iteration: 125 ended ----------------------------------------------------------------
# Iteration: 126 started  ----------------------------------------------------------------
# Iteration: 126 ended ----------------------------------------------------------------
# Iteration: 127 started  ----------------------------------------------------------------
# task: 43 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 127 ended ----------------------------------------------------------------
# Iteration: 128 started  ----------------------------------------------------------------
# Iteration: 128 ended ----------------------------------------------------------------
# Iteration: 129 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 129 ended ----------------------------------------------------------------
# Iteration: 130 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 44 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 130 ended ----------------------------------------------------------------
# Iteration: 131 started  ----------------------------------------------------------------
# Iteration: 131 ended ----------------------------------------------------------------
# Iteration: 132 started  ----------------------------------------------------------------
# Iteration: 132 ended ----------------------------------------------------------------
# Iteration: 133 started  ----------------------------------------------------------------
# task: 45 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 133 ended ----------------------------------------------------------------
# Iteration: 134 started  ----------------------------------------------------------------
# Iteration: 134 ended ----------------------------------------------------------------
# Iteration: 135 started  ----------------------------------------------------------------
# Iteration: 135 ended ----------------------------------------------------------------
# Iteration: 136 started  ----------------------------------------------------------------
# task: 46 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 136 ended ----------------------------------------------------------------
# Iteration: 137 started  ----------------------------------------------------------------
# Iteration: 137 ended ----------------------------------------------------------------
# Iteration: 138 started  ----------------------------------------------------------------
# Iteration: 138 ended ----------------------------------------------------------------
# Iteration: 139 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 47 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 139 ended ----------------------------------------------------------------
# Iteration: 140 started  ----------------------------------------------------------------
# Iteration: 140 ended ----------------------------------------------------------------
# Iteration: 141 started  ----------------------------------------------------------------
# Iteration: 141 ended ----------------------------------------------------------------
# Iteration: 142 started  ----------------------------------------------------------------
# task: 48 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 142 ended ----------------------------------------------------------------
# Iteration: 143 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 143 ended ----------------------------------------------------------------
# Iteration: 144 started  ----------------------------------------------------------------
# Iteration: 144 ended ----------------------------------------------------------------
# Iteration: 145 started  ----------------------------------------------------------------
# task: 49 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 145 ended ----------------------------------------------------------------
# Iteration: 146 started  ----------------------------------------------------------------
# Iteration: 146 ended ----------------------------------------------------------------
# Iteration: 147 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 147 ended ----------------------------------------------------------------
# Iteration: 148 started  ----------------------------------------------------------------
# task: 50 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 148 ended ----------------------------------------------------------------
# Iteration: 149 started  ----------------------------------------------------------------
# Iteration: 149 ended ----------------------------------------------------------------
# Iteration: 150 started  ----------------------------------------------------------------
# Iteration: 150 ended ----------------------------------------------------------------
# Iteration: 151 started  ----------------------------------------------------------------
# task: 51 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 151 ended ----------------------------------------------------------------
# Iteration: 152 started  ----------------------------------------------------------------
# Iteration: 152 ended ----------------------------------------------------------------
# Iteration: 153 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 153 ended ----------------------------------------------------------------
# Iteration: 154 started  ----------------------------------------------------------------
# task: 52 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 154 ended ----------------------------------------------------------------
# Iteration: 155 started  ----------------------------------------------------------------
# Iteration: 155 ended ----------------------------------------------------------------
# Iteration: 156 started  ----------------------------------------------------------------
# Iteration: 156 ended ----------------------------------------------------------------
# Iteration: 157 started  ----------------------------------------------------------------
# task: 53 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 157 ended ----------------------------------------------------------------
# Iteration: 158 started  ----------------------------------------------------------------
# Iteration: 158 ended ----------------------------------------------------------------
# Iteration: 159 started  ----------------------------------------------------------------
# Iteration: 159 ended ----------------------------------------------------------------
# Iteration: 160 started  ----------------------------------------------------------------
# task: 54 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 160 ended ----------------------------------------------------------------
# Iteration: 161 started  ----------------------------------------------------------------
# Iteration: 161 ended ----------------------------------------------------------------
# Iteration: 162 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 162 ended ----------------------------------------------------------------
# Iteration: 163 started  ----------------------------------------------------------------
# task: 55 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 163 ended ----------------------------------------------------------------
# Iteration: 164 started  ----------------------------------------------------------------
# Iteration: 164 ended ----------------------------------------------------------------
# Iteration: 165 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 165 ended ----------------------------------------------------------------
# Iteration: 166 started  ----------------------------------------------------------------
# task: 56 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 166 ended ----------------------------------------------------------------
# Iteration: 167 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 167 ended ----------------------------------------------------------------
# Iteration: 168 started  ----------------------------------------------------------------
# Iteration: 168 ended ----------------------------------------------------------------
# Iteration: 169 started  ----------------------------------------------------------------
# task: 57 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 169 ended ----------------------------------------------------------------
# Iteration: 170 started  ----------------------------------------------------------------
# Iteration: 170 ended ----------------------------------------------------------------
# Iteration: 171 started  ----------------------------------------------------------------
# Iteration: 171 ended ----------------------------------------------------------------
# Iteration: 172 started  ----------------------------------------------------------------
# task: 58 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 172 ended ----------------------------------------------------------------
# Iteration: 173 started  ----------------------------------------------------------------
# Iteration: 173 ended ----------------------------------------------------------------
# Iteration: 174 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 174 ended ----------------------------------------------------------------
# Iteration: 175 started  ----------------------------------------------------------------
# task: 59 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 175 ended ----------------------------------------------------------------
# Iteration: 176 started  ----------------------------------------------------------------
# Iteration: 176 ended ----------------------------------------------------------------
# Iteration: 177 started  ----------------------------------------------------------------
# Iteration: 177 ended ----------------------------------------------------------------
# Iteration: 178 started  ----------------------------------------------------------------
# task: 60 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 178 ended ----------------------------------------------------------------
# Iteration: 179 started  ----------------------------------------------------------------
# Iteration: 179 ended ----------------------------------------------------------------
# Iteration: 180 started  ----------------------------------------------------------------
# Iteration: 180 ended ----------------------------------------------------------------
# Iteration: 181 started  ----------------------------------------------------------------
# task: 61 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 181 ended ----------------------------------------------------------------
# Iteration: 182 started  ----------------------------------------------------------------
# Iteration: 182 ended ----------------------------------------------------------------
# Iteration: 183 started  ----------------------------------------------------------------
# Iteration: 183 ended ----------------------------------------------------------------
# Iteration: 184 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 62 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 184 ended ----------------------------------------------------------------
# Iteration: 185 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 185 ended ----------------------------------------------------------------
# Iteration: 186 started  ----------------------------------------------------------------
# Iteration: 186 ended ----------------------------------------------------------------
# Iteration: 187 started  ----------------------------------------------------------------
# task: 63 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 187 ended ----------------------------------------------------------------
# Iteration: 188 started  ----------------------------------------------------------------
# Iteration: 188 ended ----------------------------------------------------------------
# Iteration: 189 started  ----------------------------------------------------------------
# Iteration: 189 ended ----------------------------------------------------------------
# Iteration: 190 started  ----------------------------------------------------------------
# task: 64 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 190 ended ----------------------------------------------------------------
# Iteration: 191 started  ----------------------------------------------------------------
# Iteration: 191 ended ----------------------------------------------------------------
# Iteration: 192 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 192 ended ----------------------------------------------------------------
# Iteration: 193 started  ----------------------------------------------------------------
# task: 65 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 193 ended ----------------------------------------------------------------
# Iteration: 194 started  ----------------------------------------------------------------
# Iteration: 194 ended ----------------------------------------------------------------
# Iteration: 195 started  ----------------------------------------------------------------
# Iteration: 195 ended ----------------------------------------------------------------
# Iteration: 196 started  ----------------------------------------------------------------
# task: 66 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 196 ended ----------------------------------------------------------------
# Iteration: 197 started  ----------------------------------------------------------------
# Iteration: 197 ended ----------------------------------------------------------------
# Iteration: 198 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 198 ended ----------------------------------------------------------------
# Iteration: 199 started  ----------------------------------------------------------------
# task: 67 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 199 ended ----------------------------------------------------------------
# Iteration: 200 started  ----------------------------------------------------------------
# Iteration: 200 ended ----------------------------------------------------------------
# Iteration: 201 started  ----------------------------------------------------------------
# Iteration: 201 ended ----------------------------------------------------------------
# Iteration: 202 started  ----------------------------------------------------------------
# task: 68 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 202 ended ----------------------------------------------------------------
# Iteration: 203 started  ----------------------------------------------------------------
# Iteration: 203 ended ----------------------------------------------------------------
# Iteration: 204 started  ----------------------------------------------------------------
# Iteration: 204 ended ----------------------------------------------------------------
# Iteration: 205 started  ----------------------------------------------------------------
# task: 69 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 205 ended ----------------------------------------------------------------
# Iteration: 206 started  ----------------------------------------------------------------
# Iteration: 206 ended ----------------------------------------------------------------
# Iteration: 207 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 207 ended ----------------------------------------------------------------
# Iteration: 208 started  ----------------------------------------------------------------
# task: 70 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 208 ended ----------------------------------------------------------------
# Iteration: 209 started  ----------------------------------------------------------------
# Iteration: 209 ended ----------------------------------------------------------------
# Iteration: 210 started  ----------------------------------------------------------------
# Iteration: 210 ended ----------------------------------------------------------------
# Iteration: 211 started  ----------------------------------------------------------------
# task: 71 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 211 ended ----------------------------------------------------------------
# Iteration: 212 started  ----------------------------------------------------------------
# Iteration: 212 ended ----------------------------------------------------------------
# Iteration: 213 started  ----------------------------------------------------------------
# Iteration: 213 ended ----------------------------------------------------------------
# Iteration: 214 started  ----------------------------------------------------------------
# task: 72 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Q-table updated!!!!!!!!
# Iteration: 214 ended ----------------------------------------------------------------
# Iteration: 215 started  ----------------------------------------------------------------
# Iteration: 215 ended ----------------------------------------------------------------
# Iteration: 216 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 216 ended ----------------------------------------------------------------
# Iteration: 217 started  ----------------------------------------------------------------
# task: 73 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 217 ended ----------------------------------------------------------------
# Iteration: 218 started  ----------------------------------------------------------------
# Iteration: 218 ended ----------------------------------------------------------------
# Iteration: 219 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 219 ended ----------------------------------------------------------------
# Iteration: 220 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 74 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 220 ended ----------------------------------------------------------------
# Iteration: 221 started  ----------------------------------------------------------------
# Iteration: 221 ended ----------------------------------------------------------------
# Iteration: 222 started  ----------------------------------------------------------------
# Iteration: 222 ended ----------------------------------------------------------------
# Iteration: 223 started  ----------------------------------------------------------------
# task: 75 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 223 ended ----------------------------------------------------------------
# Iteration: 224 started  ----------------------------------------------------------------
# Iteration: 224 ended ----------------------------------------------------------------
# Iteration: 225 started  ----------------------------------------------------------------
# Iteration: 225 ended ----------------------------------------------------------------
# Iteration: 226 started  ----------------------------------------------------------------
# task: 76 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 226 ended ----------------------------------------------------------------
# Iteration: 227 started  ----------------------------------------------------------------
# Iteration: 227 ended ----------------------------------------------------------------
# Iteration: 228 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 228 ended ----------------------------------------------------------------
# Iteration: 229 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 77 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 229 ended ----------------------------------------------------------------
# Iteration: 230 started  ----------------------------------------------------------------
# Iteration: 230 ended ----------------------------------------------------------------
# Iteration: 231 started  ----------------------------------------------------------------
# Iteration: 231 ended ----------------------------------------------------------------
# Iteration: 232 started  ----------------------------------------------------------------
# task: 78 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 232 ended ----------------------------------------------------------------
# Iteration: 233 started  ----------------------------------------------------------------
# Iteration: 233 ended ----------------------------------------------------------------
# ...
# Q-table updated!!!!!!!!
# Iteration: 450 ended ----------------------------------------------------------------
# Iteration: 451 started  ----------------------------------------------------------------
# task: 151 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Iteration: 451 ended ----------------------------------------------------------------
# Iteration: 452 started  ----------------------------------------------------------------
# Iteration: 452 ended ----------------------------------------------------------------
# Iteration: 453 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 453 ended ----------------------------------------------------------------
# Iteration: 454 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 152 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 454 ended ----------------------------------------------------------------
# Iteration: 455 started  ----------------------------------------------------------------
# Iteration: 455 ended ----------------------------------------------------------------
# Iteration: 456 started  ----------------------------------------------------------------
# Iteration: 456 ended ----------------------------------------------------------------
# Iteration: 457 started  ----------------------------------------------------------------
# task: 153 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 457 ended ----------------------------------------------------------------
# Iteration: 458 started  ----------------------------------------------------------------
# Iteration: 458 ended ----------------------------------------------------------------
# Iteration: 459 started  ----------------------------------------------------------------
# Iteration: 459 ended ----------------------------------------------------------------
# Iteration: 460 started  ----------------------------------------------------------------
# task: 154 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 460 ended ----------------------------------------------------------------
# Iteration: 461 started  ----------------------------------------------------------------
# Iteration: 461 ended ----------------------------------------------------------------
# Iteration: 462 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 462 ended ----------------------------------------------------------------
# Iteration: 463 started  ----------------------------------------------------------------
# task: 155 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 463 ended ----------------------------------------------------------------
# Iteration: 464 started  ----------------------------------------------------------------
# Iteration: 464 ended ----------------------------------------------------------------
# Iteration: 465 started  ----------------------------------------------------------------
# Iteration: 465 ended ----------------------------------------------------------------
# Iteration: 466 started  ----------------------------------------------------------------
# task: 156 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 466 ended ----------------------------------------------------------------
# Iteration: 467 started  ----------------------------------------------------------------
# Iteration: 467 ended ----------------------------------------------------------------
# Iteration: 468 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 468 ended ----------------------------------------------------------------
# Iteration: 469 started  ----------------------------------------------------------------
# task: 157 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 469 ended ----------------------------------------------------------------
# Iteration: 470 started  ----------------------------------------------------------------
# Iteration: 470 ended ----------------------------------------------------------------
# Iteration: 471 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 471 ended ----------------------------------------------------------------
# Iteration: 472 started  ----------------------------------------------------------------
# task: 158 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 472 ended ----------------------------------------------------------------
# Iteration: 473 started  ----------------------------------------------------------------
# Iteration: 473 ended ----------------------------------------------------------------
# Iteration: 474 started  ----------------------------------------------------------------
# Iteration: 474 ended ----------------------------------------------------------------
# Iteration: 475 started  ----------------------------------------------------------------
# task: 159 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Iteration: 475 ended ----------------------------------------------------------------
# Iteration: 476 started  ----------------------------------------------------------------
# Iteration: 476 ended ----------------------------------------------------------------
# Iteration: 477 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 477 ended ----------------------------------------------------------------
# Iteration: 478 started  ----------------------------------------------------------------
# task: 160 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 478 ended ----------------------------------------------------------------
# Iteration: 479 started  ----------------------------------------------------------------
# Iteration: 479 ended ----------------------------------------------------------------
# Iteration: 480 started  ----------------------------------------------------------------
# Iteration: 480 ended ----------------------------------------------------------------
# Iteration: 481 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 161 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 481 ended ----------------------------------------------------------------
# Iteration: 482 started  ----------------------------------------------------------------
# Iteration: 482 ended ----------------------------------------------------------------
# Iteration: 483 started  ----------------------------------------------------------------
# Iteration: 483 ended ----------------------------------------------------------------
# Iteration: 484 started  ----------------------------------------------------------------
# task: 162 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 484 ended ----------------------------------------------------------------
# Iteration: 485 started  ----------------------------------------------------------------
# Iteration: 485 ended ----------------------------------------------------------------
# Iteration: 486 started  ----------------------------------------------------------------
# Iteration: 486 ended ----------------------------------------------------------------
# Iteration: 487 started  ----------------------------------------------------------------
# task: 163 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 487 ended ----------------------------------------------------------------
# Iteration: 488 started  ----------------------------------------------------------------
# Iteration: 488 ended ----------------------------------------------------------------
# Iteration: 489 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 489 ended ----------------------------------------------------------------
# Iteration: 490 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# task: 164 locaction: edge_server 8, energy:0.25, execution_time:1
# Iteration: 490 ended ----------------------------------------------------------------
# Iteration: 491 started  ----------------------------------------------------------------
# Iteration: 491 ended ----------------------------------------------------------------
# Iteration: 492 started  ----------------------------------------------------------------
# Iteration: 492 ended ----------------------------------------------------------------
# Iteration: 493 started  ----------------------------------------------------------------
# task: 165 locaction: local at 1, energy:0.0006999999999999999, execution_time:7
# Q-table updated!!!!!!!!
# Iteration: 493 ended ----------------------------------------------------------------
# Iteration: 494 started  ----------------------------------------------------------------
# Iteration: 494 ended ----------------------------------------------------------------
# Iteration: 495 started  ----------------------------------------------------------------
# Iteration: 495 ended ----------------------------------------------------------------
# Iteration: 496 started  ----------------------------------------------------------------
# task: 166 locaction: local at 1, energy:0.00019999999999999998, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 496 ended ----------------------------------------------------------------
# Iteration: 497 started  ----------------------------------------------------------------
# Iteration: 497 ended ----------------------------------------------------------------
# Iteration: 498 started  ----------------------------------------------------------------
# Iteration: 498 ended ----------------------------------------------------------------
# Iteration: 499 started  ----------------------------------------------------------------
# task: 167 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Iteration: 499 ended ----------------------------------------------------------------
# Iteration: 500 started  ----------------------------------------------------------------
# Iteration: 500 ended ----------------------------------------------------------------
# Iteration: 501 started  ----------------------------------------------------------------
# Iteration: 501 ended ----------------------------------------------------------------
# Iteration: 502 started  ----------------------------------------------------------------
# task: 168 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 502 ended ----------------------------------------------------------------
# Iteration: 503 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 503 ended ----------------------------------------------------------------
# Iteration: 504 started  ----------------------------------------------------------------
# Iteration: 504 ended ----------------------------------------------------------------
# Iteration: 505 started  ----------------------------------------------------------------
# task: 169 locaction: edge_server 8, energy:0.1, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 505 ended ----------------------------------------------------------------
# Iteration: 506 started  ----------------------------------------------------------------
# Iteration: 506 ended ----------------------------------------------------------------
# Iteration: 507 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 507 ended ----------------------------------------------------------------
# Iteration: 508 started  ----------------------------------------------------------------
# task: 170 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 508 ended ----------------------------------------------------------------
# Iteration: 509 started  ----------------------------------------------------------------
# Iteration: 509 ended ----------------------------------------------------------------
# Iteration: 510 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 510 ended ----------------------------------------------------------------
# Iteration: 511 started  ----------------------------------------------------------------
# task: 171 locaction: edge_server 8, energy:0.35, execution_time:2
# Q-table updated!!!!!!!!
# Iteration: 511 ended ----------------------------------------------------------------
# Iteration: 512 started  ----------------------------------------------------------------
# Iteration: 512 ended ----------------------------------------------------------------
# Iteration: 513 started  ----------------------------------------------------------------
# Iteration: 513 ended ----------------------------------------------------------------
# Iteration: 514 started  ----------------------------------------------------------------
# task: 172 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 514 ended ----------------------------------------------------------------
# Iteration: 515 started  ----------------------------------------------------------------
# Iteration: 515 ended ----------------------------------------------------------------
# Iteration: 516 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 516 ended ----------------------------------------------------------------
# Iteration: 517 started  ----------------------------------------------------------------
# task: 173 locaction: local at 1, energy:0.0004999999999999999, execution_time:5
# Q-table updated!!!!!!!!
# Iteration: 517 ended ----------------------------------------------------------------
# Iteration: 518 started  ----------------------------------------------------------------
# Iteration: 518 ended ----------------------------------------------------------------
# Iteration: 519 started  ----------------------------------------------------------------
# Iteration: 519 ended ----------------------------------------------------------------
# Iteration: 520 started  ----------------------------------------------------------------
# task: 174 locaction: edge_server 8, energy:0.35, execution_time:2
# Iteration: 520 ended ----------------------------------------------------------------
# Iteration: 521 started  ----------------------------------------------------------------
# Iteration: 521 ended ----------------------------------------------------------------
# Iteration: 522 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 522 ended ----------------------------------------------------------------
# Iteration: 523 started  ----------------------------------------------------------------
# task: 175 locaction: edge_server 8, energy:0.1, execution_time:1
# Iteration: 523 ended ----------------------------------------------------------------
# Iteration: 524 started  ----------------------------------------------------------------
# Iteration: 524 ended ----------------------------------------------------------------
# Iteration: 525 started  ----------------------------------------------------------------
# Q-table updated!!!!!!!!
# Iteration: 525 ended ----------------------------------------------------------------
# Iteration: 526 started  ----------------------------------------------------------------
# task: 176 locaction: edge_server 8, energy:0.25, execution_time:1
# Q-table updated!!!!!!!!
# Iteration: 526 ended ----------------------------------------------------------------
# Iteration: 527 started  ----------------------------------------------------------------
